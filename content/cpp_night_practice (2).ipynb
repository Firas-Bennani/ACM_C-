# %% [markdown]
# # 🎮 C++ NIGHT — Practice Arena
# **ACM ENSTAB**
#
# Every question is a small piece of C++ from the slides with some parts missing: `__1__`, `__2__`…
#
# **How to play:**
# 1. **Run the SETUP cell below FIRST** (click it, then `Shift + Enter`). If you reopen the notebook or restart the kernel, run it again.
# 2. For each question, write what goes in each blank **between the quotes** (`blank1 = r"..."`).
#    Only the missing part: no `;`, spaces don't matter.
# 3. Run the answer cell, then the **check** cell under it. You get 1 point per correct blank.
# 4. At the end, write your name and run the **SUBMIT** cell.
#
# **34 questions · 61 points · ~30 seconds each.** Good luck! ⚔️

# %%
# ⚙️ SETUP — run this cell first (Shift + Enter). Do not modify it.
import hashlib, re, json, datetime

LEADERBOARD_URL = "https://script.google.com/macros/s/AKfycbwv2uLf2uwp7wyU5BRGDipfwmlxYtfzgbpozIrq4KgXLROX-1G2bHtyuCoYi4LFtDyB/exec"   # set by the organiser
GRADING_MODE = False     # True only when grading with nbgrader (wrong answers then raise AssertionError)

_KEY = {"Q01": [["4e0482221ff6d12c"]], "Q02": [["9359f3bb2efa7aab"]], "Q03": [["6da88c34ba124c41"], ["5feceb66ffc86f38"]], "Q04": [["0f02c6bad08d9ff1"], ["4be261c018f23dea"]], "Q05": [["6da88c34ba124c41", "dfeeff5e6648b448"], ["ed7aa50d187fda24"], ["4be261c018f23dea"]], "Q06": [["f50afd709229bfdf"], ["a80e516bfb196e1c"]], "Q07": [["6da88c34ba124c41", "dfeeff5e6648b448"], ["380918b946a52664"]], "Q08": [["6da88c34ba124c41", "dfeeff5e6648b448"], ["dfeeff5e6648b448", "2aaec3bad98c2e6c"]], "Q09": [["2ce06a9e7f8c3e6b", "76a7e234dc54e9c6", "fc76c92c5966e7fc"]], "Q10": [["411b0496da5eeced"], ["ca978112ca1bbdca"]], "Q11": [["0f02c6bad08d9ff1"]], "Q12": [["a16266d0e4a47188"]], "Q13": [["ccdcbe846f3da4eb", "0f82aca66af91493"]], "Q14": [["e6640de835ad09fb"], ["d4735e3a265e16ee"]], "Q15": [["b5bea41b6c623f7c"]], "Q16": [["6254c28f7a630493"], ["d8156bae0c4243d3"]], "Q17": [["a6eafa8e90b1ea84", "03dffaaa40e52b8a", "03210ee21ad78921"], ["7dd530c4d36da47c"]], "Q18": [["9f428c0e7dfd81ad"]], "Q19": [["6b86b273ff34fce1"], ["ef2d127de37b942b"], ["e8dee0e1e379cafd", "91fb2ac118c32027", "c4b8ea716f1439f3", "8e4fe4d049d11ee8"]], "Q20": [["0604cd3138feed20"]], "Q21": [["dabd3aff769f07eb"], ["cfc0c0607a3380f7"], ["4e07408562bedb8b"]], "Q22": [["4a44dc15364204a8"], ["19581e27de7ced00"]], "Q23": [["1b16b1df538ba12d"], ["de7d1b721a1e0632"]], "Q24": [["1b16b1df538ba12d"], ["0365fb29cd405735"]], "Q25": [["6da88c34ba124c41"], ["ef2d127de37b942b"]], "Q26": [["2ff05d1573f09fae"], ["418d287704e3dac2"], ["ccdcbe846f3da4eb"]], "Q27": [["e6f07d43b5c21db0"], ["361e48d0308f20e3"]], "Q28": [["4e07408562bedb8b"], ["4b227777d4dd1fc6"], ["189f40034be7a199"]], "Q29": [["e7ac0786668e0ff0"]], "Q30": [["4e07408562bedb8b"], ["d4735e3a265e16ee"]], "Q31": [["1e22560cee2c4b72"]], "Q32": [["bf545fd4b4f8d375"], ["4e07408562bedb8b"]], "Q33": [["6da88c34ba124c41", "dfeeff5e6648b448"], ["94419b99b12c1113"]], "Q34": [["d18d38ff0cf1c680", "f24d87df3d39bf0c"]]}
TOTAL_POINTS = 61
RESULTS = {}
ANSWERS = {}

def _norm(s):
    s = re.sub(r"\s+", "", str(s))
    return s.rstrip(";").lower()

def _h(s):
    return hashlib.sha256(_norm(s).encode()).hexdigest()[:16]

def check(qid, *blanks):
    """Checks your blanks, prints feedback and records your points."""
    expected = _KEY[qid]
    ANSWERS[qid] = [str(b) for b in blanks]
    pts = 0
    lines = []
    for i, (b, alts) in enumerate(zip(blanks, expected), start=1):
        if str(b).strip() == "":
            lines.append(f"   blank {i}: ⬜ empty")
        elif _h(b) in alts:
            pts += 1
            lines.append(f"   blank {i}: ✅")
        else:
            lines.append(f"   blank {i}: ❌")
    RESULTS[qid] = (pts, len(expected))
    icon = "🏆" if pts == len(expected) else ("👍" if pts else "💥")
    print(f"{icon} {qid}: {pts}/{len(expected)} point(s)")
    print("\n".join(lines))
    print(f"   Current total: {sum(p for p, _ in RESULTS.values())}/{TOTAL_POINTS}")
    if GRADING_MODE:
        assert pts == len(expected), f"{qid}: {pts}/{len(expected)}"

print("✅ Setup done. Scroll down and start with Q01!")

# %% [markdown]
# ---
# ## Q01 · #include
# <sub>Slide 5 · 1 point</sub>
#
# **Include the whole standard library in one line.**
#
# ```cpp
# #include <__1__>
# ```

# %%
# ✏️ Q01 — your answer(s)
blank1 = r""

# %%
try:
    check("Q01", blank1)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q02 · using namespace std
# <sub>Slide 6 · 1 point</sub>
#
# **Allow writing `cout` instead of `std::cout`.**
#
# ```cpp
# using __1__ std;
# ```

# %%
# ✏️ Q02 — your answer(s)
blank1 = r""

# %%
try:
    check("Q02", blank1)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q03 · int main()
# <sub>Slide 7 · 2 points</sub>
#
# **Complete the entry point of the program and its last line.**
#
# ```cpp
# __1__ main() {
#     // ...
#     return __2__;
# }
# ```

# %%
# ✏️ Q03 — your answer(s)
blank1 = r""
blank2 = r""

# %%
try:
    check("Q03", blank1, blank2)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q04 · cin / cout
# <sub>Slide 10-11 · 2 points</sub>
#
# **Read a value into `x`, then print it.**
#
# ```cpp
# cin __1__ x;
# cout __2__ x;
# ```

# %%
# ✏️ Q04 — your answer(s)
blank1 = r""
blank2 = r""

# %%
try:
    check("Q04", blank1, blank2)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q05 · Input / Output example
# <sub>Slide 12-14 · 3 points</sub>
#
# **Declare an integer `bugs`, read it, and print it after the message.**
#
# ```cpp
# __1__ bugs;
# cin >> __2__;
# cout << "Current number of bugs: " __3__ bugs;
# ```

# %%
# ✏️ Q05 — your answer(s)
blank1 = r""
blank2 = r""
blank3 = r""

# %%
try:
    check("Q05", blank1, blank2, blank3)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q06 · New line
# <sub>Slide 15 · 2 points</sub>
#
# **Two ways to go to a new line.**
#
# ```cpp
# cout << __1__;
# cout << "__2__";
# ```

# %%
# ✏️ Q06 — your answer(s)
blank1 = r""
blank2 = r""

# %%
try:
    check("Q06", blank1, blank2)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q07 · Declaring a variable
# <sub>Slide 16 · 2 points</sub>
#
# **Declare an integer variable `score` equal to 10.**
#
# ```cpp
# __1__ score __2__ 10;
# ```

# %%
# ✏️ Q07 — your answer(s)
blank1 = r""
blank2 = r""

# %%
try:
    check("Q07", blank1, blank2)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q08 · int or long long?
# <sub>Slide 17-19 · 2 points</sub>
#
# **Constraints: 1 &le; n &le; 10<sup>6</sup>. Choose the right type for `n`, then for `n * n` (up to 10<sup>12</sup>).**
#
# ```cpp
# __1__ n;
# cin >> n;
# __2__ square = 1LL * n * n;
# ```

# %%
# ✏️ Q08 — your answer(s)
blank1 = r""
blank2 = r""

# %%
try:
    check("Q08", blank1, blank2)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q09 · double
# <sub>Slide 20 · 1 point</sub>
#
# **Declare a decimal variable `pi` equal to 3.14.**
#
# ```cpp
# __1__ pi = 3.14;
# ```

# %%
# ✏️ Q09 — your answer(s)
blank1 = r""

# %%
try:
    check("Q09", blank1)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q10 · char
# <sub>Slide 21 · 2 points</sub>
#
# **Declare a character variable `grade` holding the letter A.**
#
# ```cpp
# __1__ grade = '__2__';
# ```

# %%
# ✏️ Q10 — your answer(s)
blank1 = r""
blank2 = r""

# %%
try:
    check("Q10", blank1, blank2)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q11 · string: one word
# <sub>Slide 22 · 1 point</sub>
#
# **Read ONE word into `name`.**
#
# ```cpp
# string name;
# cin __1__ name;
# ```

# %%
# ✏️ Q11 — your answer(s)
blank1 = r""

# %%
try:
    check("Q11", blank1)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q12 · string: whole line
# <sub>Slide 23 · 1 point</sub>
#
# **Read the WHOLE line into `line`.**
#
# ```cpp
# string line;
# __1__(cin, line);
# ```

# %%
# ✏️ Q12 — your answer(s)
blank1 = r""

# %%
try:
    check("Q12", blank1)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q13 · string: length
# <sub>Slide 24 · 1 point</sub>
#
# **Store the length of `s` in `len`.**
#
# ```cpp
# string s = "EnstaByte";
# int len = s.__1__();
# ```

# %%
# ✏️ Q13 — your answer(s)
blank1 = r""

# %%
try:
    check("Q13", blank1)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q14 · string: find
# <sub>Slide 25 · 2 points</sub>
#
# **Find the position of `'l'` in `"hello"`. Blank 2: what number is printed?**
#
# ```cpp
# string s = "hello";
# cout << s.__1__('l');   // prints __2__
# ```

# %%
# ✏️ Q14 — your answer(s)
blank1 = r""
blank2 = r""

# %%
try:
    check("Q14", blank1, blank2)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q15 · bool
# <sub>Slide 26 · 1 point</sub>
#
# **The player has won: complete the boolean.**
#
# ```cpp
# bool hasWon = __1__;
# ```

# %%
# ✏️ Q15 — your answer(s)
blank1 = r""

# %%
try:
    check("Q15", blank1)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q16 · Update / assignment
# <sub>Slide 28 · 2 points</sub>
#
# **Blank 1: add 50 to `score`. Blank 2: remove one life.**
#
# ```cpp
# score __1__ 50;
# lives__2__;
# ```

# %%
# ✏️ Q16 — your answer(s)
blank1 = r""
blank2 = r""

# %%
try:
    check("Q16", blank1, blank2)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q17 · Conditional statements
# <sub>Slide 29-31 · 2 points</sub>
#
# **Read the number of lives `l`. If there are lives left, print "Keep playing!", otherwise print "GAME OVER!".**
#
# ```cpp
# int l;
# cin >> l;
# if (__1__) {
#     cout << "Keep playing!";
# }
# __2__ {
#     cout << "GAME OVER!";
# }
# ```

# %%
# ✏️ Q17 — your answer(s)
blank1 = r""
blank2 = r""

# %%
try:
    check("Q17", blank1, blank2)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q18 · else if
# <sub>Slide 29 · 1 point</sub>
#
# **Grade: 90 or more &rarr; A, 50 or more &rarr; B, otherwise &rarr; C.**
#
# ```cpp
# if (score >= 90) {
#     cout << 'A';
# }
# __1__ (score >= 50) {
#     cout << 'B';
# }
# else {
#     cout << 'C';
# }
# ```

# %%
# ✏️ Q18 — your answer(s)
blank1 = r""

# %%
try:
    check("Q18", blank1)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q19 · for: syntax
# <sub>Slide 32 · 3 points</sub>
#
# **Print the numbers 1 to 5.**
#
# ```cpp
# for (int i = __1__; i <= __2__; __3__) {
#     cout << i << ' ';
# }
# ```

# %%
# ✏️ Q19 — your answer(s)
blank1 = r""
blank2 = r""
blank3 = r""

# %%
try:
    check("Q19", blank1, blank2, blank3)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q20 · for: score
# <sub>Slide 33-35 · 1 point</sub>
#
# **What is the value of `score` after the loop?**
#
# ```cpp
# int score = 0;
# for (int i = 1; i <= 5; i++) {
#     score += 100;
# }
# // score = __1__
# ```

# %%
# ✏️ Q20 — your answer(s)
blank1 = r""

# %%
try:
    check("Q20", blank1)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q21 · while
# <sub>Slide 36-38 · 3 points</sub>
#
# **Print "Keep trying!" while `t` is less than 3. Blank 3: how many times is it printed?**
#
# ```cpp
# int t = 0;
# while (t __1__ 3) {
#     cout << "Keep trying!\n";
#     t__2__;
# }
# // printed __3__ times
# ```

# %%
# ✏️ Q21 — your answer(s)
blank1 = r""
blank2 = r""
blank3 = r""

# %%
try:
    check("Q21", blank1, blank2, blank3)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q22 · Arrays: declaration
# <sub>Slide 40 · 2 points</sub>
#
# **Declare an array of 10 integers. Blank 2: index of the LAST element.**
#
# ```cpp
# int arr[__1__];
# // last element: arr[__2__]
# ```

# %%
# ✏️ Q22 — your answer(s)
blank1 = r""
blank2 = r""

# %%
try:
    check("Q22", blank1, blank2)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q23 · Arrays: reading input
# <sub>Slide 41 · 2 points</sub>
#
# **Read `n` numbers into the array `a`.**
#
# ```cpp
# for (int i = 0; i < __1__; i++) {
#     cin >> a[__2__];
# }
# ```

# %%
# ✏️ Q23 — your answer(s)
blank1 = r""
blank2 = r""

# %%
try:
    check("Q23", blank1, blank2)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q24 · Arrays: sorting
# <sub>Slide 42 · 2 points</sub>
#
# **Blank 1: sort `a` (size `n`) in ascending order. Blank 2: the third argument for DESCENDING order.**
#
# ```cpp
# sort(a, a + __1__);
# sort(a, a + n, __2__);
# ```

# %%
# ✏️ Q24 — your answer(s)
blank1 = r""
blank2 = r""

# %%
try:
    check("Q24", blank1, blank2)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q25 · Vectors: declaration
# <sub>Slide 43 · 2 points</sub>
#
# **Blank 1: an empty vector of integers. Blank 2: a vector containing five zeros.**
#
# ```cpp
# vector<__1__> v;
# vector<int> w(__2__);
# ```

# %%
# ✏️ Q25 — your answer(s)
blank1 = r""
blank2 = r""

# %%
try:
    check("Q25", blank1, blank2)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q26 · Vectors: operations
# <sub>Slide 44 · 3 points</sub>
#
# **Add `x` at the end, remove the last element, get the number of elements.**
#
# ```cpp
# v.__1__(x);
# v.__2__();
# int k = v.__3__();
# ```

# %%
# ✏️ Q26 — your answer(s)
blank1 = r""
blank2 = r""
blank3 = r""

# %%
try:
    check("Q26", blank1, blank2, blank3)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q27 · Vectors: sorting
# <sub>Slide 44 · 2 points</sub>
#
# **Sort the whole vector in ascending order.**
#
# ```cpp
# sort(v.__1__(), v.__2__());
# ```

# %%
# ✏️ Q27 — your answer(s)
blank1 = r""
blank2 = r""

# %%
try:
    check("Q27", blank1, blank2)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q28 · Matrix
# <sub>Slide 45 · 3 points</sub>
#
# **Declare a matrix of 3 rows and 4 columns, then complete the reading loop.**
#
# ```cpp
# int a[__1__][__2__];
# for (int i = 0; i < 3; i++) {
#     for (int j = 0; j < 4; j++) {
#         cin >> a[i][__3__];
#     }
# }
# ```

# %%
# ✏️ Q28 — your answer(s)
blank1 = r""
blank2 = r""
blank3 = r""

# %%
try:
    check("Q28", blank1, blank2, blank3)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q29 · Parcours des sets, multisets and maps
# <sub>Slide 46 · 1 point</sub>
#
# **Loop over every element of the set `s`.**
#
# ```cpp
# for (int x __1__ s) {
#     cout << x << ' ';
# }
# ```

# %%
# ✏️ Q29 — your answer(s)
blank1 = r""

# %%
try:
    check("Q29", blank1)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q30 · set
# <sub>Slide 47 · 2 points</sub>
#
# **How many elements does `s` contain? Blank 2: which element is printed FIRST?**
#
# ```cpp
# set<int> s = {4, 4, 2, 9, 2};
# // s.size() = __1__
# // first element printed: __2__
# ```

# %%
# ✏️ Q30 — your answer(s)
blank1 = r""
blank2 = r""

# %%
try:
    check("Q30", blank1, blank2)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q31 · set: insert
# <sub>Slide 48 · 1 point</sub>
#
# **Add `x` to the set.**
#
# ```cpp
# set<int> s;
# int x;
# cin >> x;
# s.__1__(x);
# ```

# %%
# ✏️ Q31 — your answer(s)
blank1 = r""

# %%
try:
    check("Q31", blank1)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q32 · multiset
# <sub>Slide 49 · 2 points</sub>
#
# **Blank 1: the container that is sorted AND keeps duplicates. Blank 2: how many elements does it contain?**
#
# ```cpp
# __1__<int> ms = {3, 1, 3};
# // ms.size() = __2__
# ```

# %%
# ✏️ Q32 — your answer(s)
blank1 = r""
blank2 = r""

# %%
try:
    check("Q32", blank1, blank2)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q33 · map
# <sub>Slide 50 · 2 points</sub>
#
# **Map a name (string) to an age (integer), then print Ali's age.**
#
# ```cpp
# map<string, __1__> age;
# age["Ali"] = 20;
# cout << age["__2__"];   // prints 20
# ```

# %%
# ✏️ Q33 — your answer(s)
blank1 = r""
blank2 = r""

# %%
try:
    check("Q33", blank1, blank2)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# ## Q34 · Codeforces
# <sub>Slide 51 · 1 point</sub>
#
# **Your solution is correct but too slow. Which verdict do you get? (short form accepted)**
#
# ```cpp
# // Verdict: __1__
# ```

# %%
# ✏️ Q34 — your answer(s)
blank1 = r""

# %%
try:
    check("Q34", blank1)
except NameError as e:
    if "check" in str(e):
        print("⚠️  The SETUP cell has not been run. Scroll to the top, click the SETUP cell, press Shift + Enter, then run this cell again.")
    else:
        print("⚠️  Run your answer cell (just above) first, then run this cell again.")

# %% [markdown]
# ---
# # 🏁 Finish line
# Write your name (the one that will appear on the leaderboard), then run the two cells below.

# %%
STUDENT_NAME = ""   # e.g. "Yasmine B."

# %%
# 🚀 SUBMIT YOUR SCORE — run this cell when you are done (you can run it again to update)
async def _send(payload):
    body = json.dumps(payload)
    try:
        from pyodide.http import pyfetch            # JupyterLite (runs in the browser)
        await pyfetch(LEADERBOARD_URL, method="POST", body=body,
                      headers={"Content-Type": "text/plain"}, mode="no-cors")
    except ImportError:                              # classic Jupyter / JupyterHub
        import urllib.request
        req = urllib.request.Request(LEADERBOARD_URL, data=body.encode(),
                                     headers={"Content-Type": "text/plain"})
        urllib.request.urlopen(req, timeout=15)

if STUDENT_NAME.strip() == "":
    print("⚠️  Write your name in the cell above first!")
elif "PASTE_YOUR" in LEADERBOARD_URL:
    print("⚠️  No leaderboard URL configured. Your local score is:",
          sum(p for p, _ in RESULTS.values()), "/", TOTAL_POINTS)
else:
    score = sum(p for p, _ in RESULTS.values())
    await _send({"name": STUDENT_NAME.strip(), "answers": ANSWERS, "local_score": score})
    print(f"📨 Sent! {STUDENT_NAME.strip()} — {score}/{TOTAL_POINTS}")
    print("Look at the leaderboard on the big screen 👀")
